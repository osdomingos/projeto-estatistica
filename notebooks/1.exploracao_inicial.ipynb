# %% [markdown]
# # PROJETO - <strong>Ciência de Dados</strong> - Disciplina <i>Estatística</i>
# ## <i>Análise estatística do acervo do MoMA</i>
# ###### por Osmar Domingos

# %% [markdown]
# #### fonte dos dados: <a src="https://github.com/MuseumofModernArt/collection">MoMA Collection</a>
# ###### Data de Coleta: 04/04/2026

# %% [markdown]
# <img src="https://www.moma.org/d/p/sa/07-29-24_240518_MoMA%20Family%20Programs_036_large_NT.jpg">

# %% [markdown]
# ### 1ª Etapa <i>O que existe aqui e o que está faltando?</i>

# %% [markdown]
# A fazer (4/4 - 10/4/2026):
#
# <i>
# <ol>
#     <li>Carregar o dataset do MoMA [✅]</li>
#     <li>Mapear colunas disponíveis [❌]</li>
#     <li>Limpeza inicial: nulos, tipos, inconsistências [❌]</li>
# </ol>
# </i>

# %% [markdown]
# <hr>

# %% [markdown]
# ## Carregar datasets do museu

# %% [markdown]
# <i>Bibliotecas:</i>

# %%
import pandas as pd

# %% [markdown]
# <i>Carregamento em dataframes dos arquivos .csv</i>

# %%
df_artistas = pd.read_csv("../data/raw/Artists.csv")
df_obras = pd.read_csv("../data/raw/Artworks.csv")

# %% [markdown]
# <i style="background-color: 'blue'">Gerar amostras de 10 casos de cada dataframe, tendo assim uma ideia inicial da estrutura do dataset sem ver apenas os primeiros ou últimos, para  que o olhar sobre este seja mais exploratório</i>

# %%
df_artistas.sample(10)
# Out:
#        ConstituentID               DisplayName             ArtistBio  \
# 8795           21446              Jack Pierson   American, born 1960
# 3021            3389          Mikhail Larionov    Russian, 1881–1964
# 14542          67947    Juan Manuel Echavarría  Colombian, born 1947
# 14708          69743          Flaminio Bertoni    Italian, 1903–1964
# 3782            4217          Hitoshi Nakazato   Japanese, 1936–2010
# 5815            6487         Ryuichi Yamashiro   Japanese, born 1920
# 5591            6237            Jo Ann Walters   American, born 1952
# 11396          34415                      BBPR          founded 1932
# 9116           23588                     N. K.                   NaN
# 8408           10913  G. Schanzenbach, Germany                   NaN
#
#       Nationality  Gender  BeginDate  EndDate  Wiki QID         ULAN
# 8795     American    male       1960        0  Q2067124  500116161.0
# 3021      Russian    male       1881     1964    Q38785  500012150.0
# 14542   Colombian    male       1947        0       NaN          NaN
# 14708     Italian    male       1903     1964       NaN          NaN
# 3782     Japanese    male       1936     2010       NaN          NaN
# 5815     Japanese    male       1920        0  Q2178400          NaN
# 5591     American  female       1952        0       NaN          NaN
# 11396         NaN     NaN       1932        0       NaN          NaN
# 9116          NaN     NaN          0        0       NaN          NaN
# 8408          NaN     NaN          0        0       NaN          NaN

# %%
df_obras.sample(10)
# Out:
#                                                     Title  \
# 151783  Ron Bacardi y Compania, S.A., Administration B...
# 117258       Study for Twenty-two Constructions from 1967
# 26415   Headpiece (page 45) from LIVRET DE FOLASTRIES,...
# 85731                                     Jewelled Greens
# 125665  House for Frederick C. Bogk, Milwaukee, Wisconsin
# 113091                   Postal Dossier (Dossier postale)
# 146571  IIT Metallurgical and Chemical Engineering Bui...
# 38507                           Ancien couvent des Carmes
# 91823                                            Untitled
# 47406   PLACE DE LA CONCORDE; FONTAINE, GARDE-MEUBLE, ...
#
#                            Artist ConstituentID  \
# 151783   Ludwig Mies van der Rohe          7166
# 117258              Fred Sandback          5143
# 26415            Aristide Maillol          3697
# 85731             Rachel Selekman         28800
# 125665         Frank Lloyd Wright          6459
# 113091           Alighiero Boetti           630
# 146571   Ludwig Mies van der Rohe          7166
# 38507                Eugène Atget           229
# 91823   Unidentified photographer          8595
# 47406                F. A. Renard          4864
#
#                                   ArtistBio Nationality BeginDate EndDate  \
# 151783  (American, born Germany. 1886–1969)  (American)    (1886)  (1969)
# 117258                (American, 1943–2003)  (American)    (1943)  (2003)
# 26415                   (French, 1861–1944)    (French)    (1861)  (1944)
# 85731                 (American, born 1963)  (American)    (1963)     (0)
# 125665                (American, 1867–1959)  (American)    (1867)  (1959)
# 113091                 (Italian, 1940–1994)   (Italian)    (1940)  (1994)
# 146571  (American, born Germany. 1886–1969)  (American)    (1886)  (1969)
# 38507                   (French, 1857–1927)    (French)    (1857)  (1927)
# 91823                                   NaN          ()       (0)     (0)
# 47406                              (French)    (French)       (0)     (0)
#
#           Gender       Date                                          Medium  \
# 151783    (male)  1957—1960                                 Pencil on paper
# 117258    (male)    c. 1986  Series of twenty-two drawings, pencil on paper
# 26415     (male)  1927-1940                                             NaN
# 85731   (female)       2003           Glass beads sewn with thread on paper
# 125665    (male)       1916      Pencil and colored pencil on tracing paper
# 113091    (male)    1969-70        Paperboard folder containing photocopies
# 146571    (male)  1945—1946                                 Pencil on paper
# 38507     (male)       1914                            Albumen silver print
# 91823         ()    c. 1900                            Gelatin silver print
# 47406         ()       1852        Salted paper print from a glass negative
#
#         ... OnView Circumference (cm) Depth (cm) Diameter (cm) Height (cm)  \
# 151783  ...    NaN                NaN        NaN           NaN         NaN
# 117258  ...    NaN                NaN        NaN           NaN   21.600000
# 26415   ...    NaN                NaN        NaN           NaN    7.400000
# 85731   ...    NaN                NaN        NaN           NaN   29.210100
# 125665  ...    NaN                NaN        0.0           NaN   57.150114
# 113091  ...    NaN                NaN        0.0           NaN   35.000000
# 146571  ...    NaN                NaN        NaN           NaN         NaN
# 38507   ...    NaN                NaN        NaN           NaN         NaN
# 91823   ...    NaN                NaN        NaN           NaN   10.300000
# 47406   ...    NaN                NaN        NaN           NaN   16.100000
#
#        Length (cm) Weight (kg)  Width (cm) Seat Height (cm) Duration (sec.)
# 151783         NaN         NaN         NaN              NaN             NaN
# 117258         NaN         NaN   27.900000              NaN             NaN
# 26415          NaN         NaN    8.300000              NaN             NaN
# 85731          NaN         NaN   22.860000              NaN             NaN
# 125665         NaN         NaN   47.942596              NaN             NaN
# 113091         NaN         NaN   25.000000              NaN             NaN
# 146571         NaN         NaN         NaN              NaN             NaN
# 38507          NaN         NaN         NaN              NaN             NaN
# 91823          NaN         NaN    6.000000              NaN             NaN
# 47406          NaN         NaN   21.700000              NaN             NaN
#
# [10 rows x 30 columns]

# %% [markdown]
# <span style="background-color: 'yellow'">A 'chave estrangeira' que relaciona artistas e obras é <strong>ConstituentID</strong>.</span>

# %% [markdown]
# <i>Quantos casos (linhas) e variáveis (colunas) tem nos DF?</i>

# %%
print(f"Artistas - Número de casos (linhas): {df_artistas.shape[0]}. Números de variáveis (colunas): {df_artistas.shape[1]}.")
# Out:
# Artistas - Número de casos (linhas): 15859. Números de variáveis (colunas): 9.

# %%
print(f"Obras - Número de casos (linhas): {df_obras.shape[0]}. Números de variáveis (colunas): {df_obras.shape[1]}.")
# Out:
# Obras - Número de casos (linhas): 160632. Números de variáveis (colunas): 30.

# %% [markdown]
# <i style="background-color: 'blue'">Quais são as variáveis de cada DF?</i>

# %% [markdown]
# Artistas:

# %%
df_artistas.columns
# Out:
# Index(['ConstituentID', 'DisplayName', 'ArtistBio', 'Nationality', 'Gender',
#        'BeginDate', 'EndDate', 'Wiki QID', 'ULAN'],
#       dtype='str')

# %%
dict_variaveis_df_artistas = {
    "Variáveis": [],
    "Tipo de dado": [],
    "Descrição": [],
    "Tipo de variável": [],
    "Ações": []
}

for column in df_artistas.columns:
    dict_variaveis_df_artistas["Variáveis"].append(column)
    dict_variaveis_df_artistas["Tipo de dado"].append(type(column).__name__)
    dict_variaveis_df_artistas["Descrição"].append('')
    dict_variaveis_df_artistas["Tipo de variável"].append('')
    dict_variaveis_df_artistas["Ações"].append('')

# %%
dict_variaveis_df_artistas
# Out:
# {'Variáveis': ['ConstituentID',
#   'DisplayName',
#   'ArtistBio',
#   'Nationality',
#   'Gender',
#   'BeginDate',
#   'EndDate',
#   'Wiki QID',
#   'ULAN'],
#  'Tipo de dado': ['str',
#   'str',
#   'str',
#   'str',
#   'str',
#   'str',
#   'str',
#   'str',
#   'str'],
#  'Descrição': ['', '', '', '', '', '', '', '', ''],
#  'Tipo de variável': ['', '', '', '', '', '', '', '', ''],
#  'Ações': ['', '', '', '', '', '', '', '', '']}

# %%
df_artistas_variaveis = pd.DataFrame(data=dict_variaveis_df_artistas)

# %%
descricoes = [
    "'Chave estrangeira' que relaciona Artistas com Obras",
    "Nome do artista/organização",
    "Nacionalidade e data de nasc. - falecimento",
    "Nacionalidade",
    "Gênero",
    "Ano de nascimento",
    "Ano de falecimento",
    "ID de busca na WikiData",
    "ID da Union List of Artist Names® da Getty Research Institue"
]

tipos_de_variaveis = [
    "numérica discreta",
    "categórica nominal",
    "categórica nominal",
    "categórica nominal",
    "categórica nominal",
    "numérica discreta",
    "numérica discreta",
    "categórica nominal",
    "categórica nominal"
]

acoes = [
    "Converter em int",
    "Nenhuma",
    "Remover: outras colunas dão conta da mesma informação de forma isolada e de mais fácil leitura e manipulação",
    "Alterar NaN para 'Nationality unknown', que já está presente no dataset",
    "Investigar se há outra indicação de gênero além de 'male' ou 'female'",
    "Converter em int para poder fazer operações de idade",
    "Converter em int para poder fazer operações",
    "Converter em URL para acesso rápido 'https://www.wikidata.org/wiki/<Wiki QID>'",
    "Primeiro remover o '.0', que não retorna nada, então converter em URL para acesso rápido 'https://www.getty.edu/vow/ULANFullDisplay?find=<ULAN>&role=&nation=&prev_page=1&subjectid=<ULAN>'"
]

for i in df_artistas_variaveis.index:
    df_artistas_variaveis.at[i, 'Descrição'] = descricoes[i]
    df_artistas_variaveis.at[i, 'Tipo de variável'] = tipos_de_variaveis[i]
    df_artistas_variaveis.at[i, 'Ações'] = acoes[i]

# %%
with pd.option_context('display.max_colwidth', None):
    display(df_artistas_variaveis)
# Out:
#        Variáveis Tipo de dado  \
# 0  ConstituentID          str
# 1    DisplayName          str
# 2      ArtistBio          str
# 3    Nationality          str
# 4         Gender          str
# 5      BeginDate          str
# 6        EndDate          str
# 7       Wiki QID          str
# 8           ULAN          str
#
#                                                       Descrição  \
# 0          'Chave estrangeira' que relaciona Artistas com Obras
# 1                                   Nome do artista/organização
# 2                   Nacionalidade e data de nasc. - falecimento
# 3                                                 Nacionalidade
# 4                                                        Gênero
# 5                                             Ano de nascimento
# 6                                            Ano de falecimento
# 7                                       ID de busca na WikiData
# 8  ID da Union List of Artist Names® da Getty Research Institue
#
#      Tipo de variável  \
# 0   numérica discreta
# 1  categórica nominal
# 2  categórica nominal
# 3  categórica nominal
# 4  categórica nominal
# 5   numérica discreta
# 6   numérica discreta
# 7  categórica nominal
# 8  categórica nominal
#
#                                                                                                                                                                                          Ações
# 0                                                                                                                                                                             Converter em int
# 1                                                                                                                                                                                      Nenhuma
# 2                                                                                 Remover: outras colunas dão conta da mesma informação de forma isolada e de mais fácil leitura e manipulação
# 3                                                                                                                      Alterar NaN para 'Nationality unknown', que já está presente no dataset
# 4                                                                                                                        Investigar se há outra indicação de gênero além de 'male' ou 'female'
# 5                                                                                                                                         Converter em int para poder fazer operações de idade
# 6                                                                                                                                                  Converter em int para poder fazer operações
# 7                                                                                                               Converter em URL para acesso rápido 'https://www.wikidata.org/wiki/<Wiki QID>'
# 8  Primeiro remover o '.0', que não retorna nada, então converter em URL para acesso rápido 'https://www.getty.edu/vow/ULANFullDisplay?find=<ULAN>&role=&nation=&prev_page=1&subjectid=<ULAN>'

# %% [markdown]
# Obras de arte:

# %%
df_obras.columns
# Out:
# Index(['Title', 'Artist', 'ConstituentID', 'ArtistBio', 'Nationality',
#        'BeginDate', 'EndDate', 'Gender', 'Date', 'Medium', 'Dimensions',
#        'CreditLine', 'AccessionNumber', 'Classification', 'Department',
#        'DateAcquired', 'Cataloged', 'ObjectID', 'URL', 'ImageURL', 'OnView',
#        'Circumference (cm)', 'Depth (cm)', 'Diameter (cm)', 'Height (cm)',
#        'Length (cm)', 'Weight (kg)', 'Width (cm)', 'Seat Height (cm)',
#        'Duration (sec.)'],
#       dtype='str')
