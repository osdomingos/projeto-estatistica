# %% [markdown]
# # PROJETO - <strong>Ciência de Dados</strong> - Disciplina <i>Estatística</i>
# ## <i>Análise estatística do acervo do MoMA</i>
# ###### por Osmar Domingos

# %% [markdown]
# #### fonte dos dados: <a src="https://github.com/MuseumofModernArt/collection">MoMA Collection</a>

# %% [markdown]
# <img src="https://www.moma.org/d/p/sa/07-29-24_240518_MoMA%20Family%20Programs_036_large_NT.jpg">

# %% [markdown]
# ### 1ª Etapa <i>O que existe aqui e o que está faltando?</i>

# %% [markdown]
# A fazer (4/4 - 10/4/2026):
#
# <i>
# <ol>
#     <li>Carregar o dataset do MoMA [✅]</li>
#     <li>Mapear colunas disponíveis [❌]</li>
#     <li>Limpeza inicial: nulos, tipos, inconsistências [❌]</li>
# </ol>
# </i>

# %% [markdown]
# <hr>

# %% [markdown]
# ## Carregar datasets do museu

# %% [markdown]
# <i>Bibliotecas:</i>

# %%
import pandas as pd

# %% [markdown]
# <i>Carregamento em dataframes dos arquivos .csv</i>

# %%
df_artistas = pd.read_csv("../data/raw/Artists.csv")
df_obras = pd.read_csv("../data/raw/Artworks.csv")

# %% [markdown]
# <i>Gerar amostras de 10 casos de cada dataframe, tendo assim uma ideia inicial da estrutura do dataset sem ver apenas os primeiros ou últimos, para  que o olhar sobre este seja mais exploratório</i>

# %%
df_artistas.sample(10)
# Out:
#        ConstituentID                       DisplayName            ArtistBio  \
# 3615            4030                     Petr Miturich   Russian, 1887–1956
# 6473            7209                   Giotto Stoppino   Italian, 1926–2011
# 14648          68785                     Irving Schott  American, 1891–1990
# 10225          28710                    Keith Mayerson  American, born 1966
# 8155           10277  Beamo Corporation, Cambridge, MA                  NaN
# 11144          32686                    Tom O'Sullivan   British, born 1967
# 1853            2092                         Lee Gatch  American, 1902–1968
# 15591         137007                      Adrian Henri   British, 1932–2000
# 13281          44936                    Antonio Puente           Venezuelan
# 951             1069                      André Chapon               French
#
#       Nationality Gender  BeginDate  EndDate   Wiki QID         ULAN
# 3615      Russian   male       1887     1956        NaN          NaN
# 6473      Italian   male       1926     2011        NaN          NaN
# 14648    American   male       1891     1990        NaN          NaN
# 10225    American   male       1966        0        NaN          NaN
# 8155          NaN    NaN          0        0        NaN          NaN
# 11144     British   male       1967        0        NaN          NaN
# 1853     American   male       1902     1968  Q15487727  500025517.0
# 15591     British   male       1932     2000        NaN          NaN
# 13281  Venezuelan   male          0        0        NaN          NaN
# 951        French   male          0        0        NaN          NaN

# %%
df_obras.sample(10)
# Out:
#                                                     Title  \
# 111220             Poster of the French National Railroad
# 134736                                          100 Boots
# 50927                                              Siesta
# 43628                        Infantry Assault, Stalingrad
# 16442   SUNDAY, proof of 1st color (supplementary suit...
# 79947   Illinois Institute of Technology, S.R. Crown H...
# 90274                                     Road to Nowhere
# 120202     Kempner House, Charlottenburg, Berlin, Germany
# 536     Maison de la Publicité Project, Paris, France ...
# 34319                               Untitled at 2,783,195
#
#                                  Artist ConstituentID  \
# 111220              Album-miscellaneous           101
# 134736                    Eleanor Antin          8183
# 50927                László Moholy-Nagy          4048
# 43628                      Georgi Zelma          7978
# 16442                     Jean Dubuffet          1633
# 79947          Ludwig Mies van der Rohe          7166
# 90274   David Byrne, Stephen R. Johnson   8200, 32196
# 120202         Ludwig Mies van der Rohe          7166
# 536                      Oscar Nitzchke          4312
# 34319                 Jonathan Borofsky           682
#
#                                              ArtistBio            Nationality  \
# 111220                                       (Various)                     ()
# 134736                           (American, born 1935)             (American)
# 50927              (American, born Hungary. 1895–1946)             (American)
# 43628   (Russian, born Tashkent, Uzbekistan.1906–1984)              (Russian)
# 16442                              (French, 1901–1985)               (French)
# 79947              (American, born Germany. 1886–1969)             (American)
# 90274                 (American, born 1952) (American)  (American) (American)
# 120202             (American, born Germany. 1886–1969)             (American)
# 536                (American, born Germany. 1900–1991)             (American)
# 34319                            (American, born 1942)             (American)
#
#             BeginDate     EndDate         Gender       Date  \
# 111220            (0)         (0)             ()  1900-1943
# 134736         (1935)         (0)       (female)    1971-73
# 50927          (1895)      (1946)         (male)       1926
# 43628          (1906)      (1984)         (male)       1943
# 16442          (1901)      (1985)         (male)  1949-1950
# 79947          (1886)      (1969)         (male)    1950-56
# 90274   (1952) (1952)  (0) (2015)  (male) (male)       1985
# 120202         (1886)      (1969)         (male)       1922
# 536            (1900)      (1991)         (male)       1936
# 34319          (1942)         (0)         (male)     (1982)
#
#                                                    Medium  ... OnView  \
# 111220                                                NaN  ...    NaN
# 134736                   Halftone reproduction (postcard)  ...    NaN
# 50927                                Gelatin silver print  ...    NaN
# 43628                                Gelatin silver print  ...    NaN
# 16442                        Lithograph, printed in color  ...    NaN
# 79947                           Pencil on Apex note paper  ...    NaN
# 90274                           Video (color, sound) \r\n  ...    NaN
# 120202                                              Print  ...    NaN
# 536     Ink, color pencil, gouache, and graphite on sp...  ...    NaN
# 34319                            Ink and gouache on paper  ...    NaN
#
#        Circumference (cm) Depth (cm) Diameter (cm) Height (cm) Length (cm)  \
# 111220                NaN        NaN           NaN         NaN         NaN
# 134736                NaN        NaN           NaN   11.400000         NaN
# 50927                 NaN        NaN           NaN   23.300000         NaN
# 43628                 NaN        NaN           NaN   20.200000         NaN
# 16442                 NaN        NaN           NaN   20.200000         NaN
# 79947                 NaN        NaN           NaN   15.240000         NaN
# 90274                 NaN        NaN           NaN         NaN         NaN
# 120202                NaN        NaN           NaN   74.295149         NaN
# 536                   NaN        NaN           NaN   71.120100         NaN
# 34319                 NaN        NaN           NaN   20.100000         NaN
#
#        Weight (kg)  Width (cm) Seat Height (cm) Duration (sec.)
# 111220         NaN         NaN              NaN             NaN
# 134736         NaN   17.800000              NaN             NaN
# 50927          NaN   17.200000              NaN             NaN
# 43628          NaN   27.300000              NaN             NaN
# 16442          NaN   20.200000              NaN             NaN
# 79947          NaN   21.590000              NaN             NaN
# 90274          NaN         NaN              NaN           244.0
# 120202         NaN   96.520193              NaN             NaN
# 536            NaN   52.070100              NaN             NaN
# 34319          NaN   15.500000              NaN             NaN
#
# [10 rows x 30 columns]

# %% [markdown]
# * A 'chave estrangeira' que relaciona artistas e obras é <strong>ConstituentID</strong>.

# %% [markdown]
# <i>Quantos casos (linhas) e variáveis (colunas) tem nos DF?</i>

# %%
print(f"Artistas - Número de casos (linhas): {df_artistas.shape[0]}. Números de variáveis (colunas): {df_artistas.shape[1]}.")
# Out:
# Artistas - Número de casos (linhas): 15859. Números de variáveis (colunas): 9.

# %%
print(f"Obras - Número de casos (linhas): {df_obras.shape[0]}. Números de variáveis (colunas): {df_obras.shape[1]}.")
# Out:
# Obras - Número de casos (linhas): 160632. Números de variáveis (colunas): 30.

# %% [markdown]
# <i>Quais são as variáveis de cada DF?</i>

# %%
df_artistas.columns
# Out:
# Index(['ConstituentID', 'DisplayName', 'ArtistBio', 'Nationality', 'Gender',
#        'BeginDate', 'EndDate', 'Wiki QID', 'ULAN'],
#       dtype='str')

# %%
df_obras.columns
# Out:
# Index(['Title', 'Artist', 'ConstituentID', 'ArtistBio', 'Nationality',
#        'BeginDate', 'EndDate', 'Gender', 'Date', 'Medium', 'Dimensions',
#        'CreditLine', 'AccessionNumber', 'Classification', 'Department',
#        'DateAcquired', 'Cataloged', 'ObjectID', 'URL', 'ImageURL', 'OnView',
#        'Circumference (cm)', 'Depth (cm)', 'Diameter (cm)', 'Height (cm)',
#        'Length (cm)', 'Weight (kg)', 'Width (cm)', 'Seat Height (cm)',
#        'Duration (sec.)'],
#       dtype='str')
